# %% [markdown]
# <a href="https://colab.research.google.com/github/Vij18eta/code-saga/blob/main/DPP_march_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Daily Practice.

# %%
def add(a,b):
  return  a+b
a=int(input("first no:"))
b=int(input("sec no:"))
add(a,b)
# Out:
# first no:5
# sec no:2
# 7

# %%
list=[1.3,1.4,5.7]
maxpos=list. index(max(list))
print(max(list))
print(maxpos+1)
# Out:
# 5.7
# 3

# %% [markdown]
# Factorial: the product of all positive integers from 1 to n.
#
# eg:
#
# 6! = 6 × 5 × 4 × 3 × 2 × 1 = 720

# %%
f=1
n=int(input("enter the integer:"))
for i in range(1,n+1):
      f*=i
print(f)
# Out:
# enter the integer:6
# 720

# %% [markdown]
# using math lib

# %%
import math
n = 6
print(math.factorial(n))
# Out:
# 720

# %% [markdown]
# using numpy, prod function.

# %%
import numpy as np
n = 6
print(np.prod(range(1, n+1)))
# Out:
# 720

# %% [markdown]
# Fibonacci sequence(depends on if it atarts wid 0 or 1)
#
# method:trad-formulae

# %%
import math
def nthfib(n):
  res=((1+math.sqrt(5))**n-(1-math.sqrt(5))**n)/(2**n*math.sqrt(5))
  print(str(res))
nthfib(12)
# Out:
# 144.00000000000006

# %% [markdown]
# using recurssion

# %%
# Function for nth Fibonacci number
def Fibonacci(n):
    if n<= 0:
        print("Incorrect input")
    # First Fibonacci number is 0
    elif n == 1:
        return 0
    # Second Fibonacci number is 1
    elif n == 2:
        return 1
    else:
        return Fibonacci(n-1)+Fibonacci(n-2)

# Driver Program

print(Fibonacci(12))
# Out:
# 89

# %% [markdown]
# array rotation

# %%
arr=[2,4,1,3,5,6]
d=2
arr[:] = arr[d:] + arr[:d]
print(arr)
# Out:
# [1, 3, 5, 6, 2, 4]

# %% [markdown]
# Rotation of the list

# %%
from collections import deque
arr=[2,4,5,6,7,8]#left rotation-{5,6,7,8,2,4}
k=2
d=deque(arr)
d.rotate(-k)
print(list(d))
# Out:
# [5, 6, 7, 8, 2, 4]

# %% [markdown]
# strings: slicing ,accessing is by index.

# %%
S='wxyzlkj'
print('1 to 4 for xyz: ',S[1:4])
# Out:
# 1 to 4 for xyz:  xyz

# %% [markdown]
# filter function has 2 parameters one is function n other iterable.
# lambda is a anonymous nameless function used instead og regular function definition.

# %%
#removal of string.
s = "hello world"
s = "".join(filter(lambda c: c != "o", s))
print(s)
# Out:
# hell wrld
